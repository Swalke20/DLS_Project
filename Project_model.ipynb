# %%
import pandas as pd

# %%
data_train_df = pd.read_csv("data_train_transformed_csv")
data_test_df = pd.read_csv("data_test_csv")

# %%
data_train_df = data_train_df.drop('Unnamed: 0', axis=1)
data_test_df = data_test_df.drop('Unnamed: 0', axis=1)

# %%
data_train_df
# Out:
#         Row ID  Wickets taken  Remaining Average Team Value  Start Team Value
# 0            0      -0.456910                      0.655180          0.607048  \
# 1            1      -0.456910                      0.655180          0.607048
# 2            3      -0.456910                      0.655180          0.607048
# 3            4      -0.456910                      0.655180          0.607048
# 4            6      -0.456910                      0.655180          0.607048
# ...        ...            ...                           ...               ...
# 329569   10570      -1.103657                      1.214153          0.919880
# 329570  199325      -0.456910                      0.841504          0.958196
# 329571  122245       0.801180                     -0.649088          0.013576
# 329572   85363       0.454629                     -0.462764         -0.406114
# 329573   25483       1.366168                     -1.580709         -1.554742
#
# ...

# %%
data_test_df
# Out:
#        Row ID  Wickets taken  Remaining Team Value
# 0           2              3                    16  \
# 1           5              3                    16
# 2          12              3                    16
# 3          16              3                    16
# 4          23              3                    16
# ...       ...            ...                   ...
# 54040  270198              2                    16
# 54041  270200              2                    16
# 54042  270207              3                    13
# 54043  270217              3                    13
# 54044  270222              3                    13
#
#        Remaining Average Team Value  Start Team Value  Ground RPO  Ground RPW
# 0                          2.000000                24        4.79       29.31  \
# 1                          2.000000                24        4.79       29.31
# 2                          2.000000                24        4.79       29.31
# ...

# %%
y_train = data_train_df['Winner_num']

# %%
X_train = data_train_df.drop('Winner_num',axis=1)

# %%
X_test = data_test_df.drop('Winner_num',axis=1)

# %%
data_train_df
# Out:
#         Row ID  Wickets taken  Remaining Average Team Value  Start Team Value
# 0            0      -0.456910                      0.655180          0.607048  \
# 1            1      -0.456910                      0.655180          0.607048
# 2            3      -0.456910                      0.655180          0.607048
# 3            4      -0.456910                      0.655180          0.607048
# 4            6      -0.456910                      0.655180          0.607048
# ...        ...            ...                           ...               ...
# 329569   10570      -1.103657                      1.214153          0.919880
# 329570  199325      -0.456910                      0.841504          0.958196
# 329571  122245       0.801180                     -0.649088          0.013576
# 329572   85363       0.454629                     -0.462764         -0.406114
# 329573   25483       1.366168                     -1.580709         -1.554742
#
# ...

# %% [markdown]
# Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train
# Out:
#         Row ID  Wickets taken  Remaining Average Team Value  Start Team Value
# 0            0      -0.456910                      0.655180          0.607048  \
# 1            1      -0.456910                      0.655180          0.607048
# 2            3      -0.456910                      0.655180          0.607048
# 3            4      -0.456910                      0.655180          0.607048
# 4            6      -0.456910                      0.655180          0.607048
# ...        ...            ...                           ...               ...
# 329569   10570      -1.103657                      1.214153          0.919880
# 329570  199325      -0.456910                      0.841504          0.958196
# 329571  122245       0.801180                     -0.649088          0.013576
# 329572   85363       0.454629                     -0.462764         -0.406114
# 329573   25483       1.366168                     -1.580709         -1.554742
#
# ...

# %%
rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16,
                                 n_jobs=-1, random_state=7)
rnd_clf.fit(X_train, y_train)

y_pred_rf = rnd_clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Sophie Folder\Birkbeck\Project\Git\DLS_Project\Project_model.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16,
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>                                  n_jobs=-1, random_state=7)
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> rnd_clf.fit(X_train, y_train)
# ...
