# %%
import pandas as pd

# %%
data_train_df = pd.read_csv("data_train_transformed_csv")
data_test_df = pd.read_csv("data_test_csv")

# %%
data_train_df = data_train_df.drop(['Unnamed: 0', 'Row ID'], axis=1)
data_test_df = data_test_df.drop(['Unnamed: 0', 'Row ID'], axis=1)

# %%
data_train_df
# Out:
#         Wickets taken  Remaining Team Value  Remaining Average Team Value
# 0           -0.456910              0.655180                      0.607048  \
# 1           -0.456910              0.655180                      0.607048
# 2           -0.456910              0.655180                      0.607048
# 3           -0.456910              0.655180                      0.607048
# 4           -0.456910              0.655180                      0.607048
# ...               ...                   ...                           ...
# 329569      -1.103657              1.214153                      0.919880
# 329570      -0.456910              0.841504                      0.958196
# 329571       0.801180             -0.649088                      0.013576
# 329572       0.454629             -0.462764                     -0.406114
# 329573       1.366168             -1.580709                     -1.554742
#
#         Start Team Value  Ground RPO  Ground RPW  Winner_num
# 0              -0.098918   -0.346523   -0.232473           1  \
# 1              -0.098918   -0.346523   -0.232473           1
# 2              -0.098918   -0.346523   -0.232473           1
# 3              -0.098918   -0.346523   -0.232473           1
# 4              -0.098918   -0.346523   -0.232473           1
# ...                  ...         ...         ...         ...
# 329569         -0.098918    0.412043    0.344080           3
# 329570          0.467671    0.252482    0.598053           3
# 329571         -0.098918    0.252482    0.341475           3
# 329572         -1.303464   -2.103724   -2.208669           3
# 329573         -1.303464    0.412043    0.344080           3
#
#         Remaining overs and balls  Remainder
# 0                        1.012697   1.075316
# 1                        1.005512   1.070467
# 2                        0.991020   1.060720
# 3                        0.983712   1.055823
# 4                        0.968972   1.026092
# ...                           ...        ...
# 329569                   0.811488   0.861623
# 329570                   0.267423   0.249775
# 329571                  -1.698283  -1.804136
# 329572                  -0.187144  -0.253504
# 329573                  -2.851100  -2.776083
#
# [329574 rows x 9 columns]

# %%
data_test_df
# Out:
#        Wickets taken  Remaining Team Value  Remaining Average Team Value
# 0                  3                    16                      2.000000  \
# 1                  3                    16                      2.000000
# 2                  3                    16                      2.000000
# 3                  3                    16                      2.000000
# 4                  3                    16                      2.000000
# ...              ...                   ...                           ...
# 54040              2                    16                      1.777778
# 54041              2                    16                      1.777778
# 54042              3                    13                      1.625000
# 54043              3                    13                      1.625000
# 54044              3                    13                      1.625000
#
#        Start Team Value  Ground RPO  Ground RPW  Winner_num
# 0                    24        4.79       29.31           1  \
# 1                    24        4.79       29.31           1
# 2                    24        4.79       29.31           1
# 3                    24        4.79       29.31           1
# 4                    24        4.79       29.31           1
# ...                 ...         ...         ...         ...
# 54040                21        5.40       31.64           2
# 54041                21        5.40       31.64           2
# 54042                21        5.40       31.64           2
# 54043                21        5.40       31.64           2
# 54044                21        5.40       31.64           2
#
#        Remaining overs and balls  Remainder
# 0                            177       29.3
# 1                            174       29.0
# 2                            167       27.5
# 3                            163       27.1
# 4                            156       26.0
# ...                          ...        ...
# 54040                         38        6.2
# 54041                         36        6.0
# 54042                         29        4.5
# 54043                         19        3.1
# 54044                         14        2.2
#
# [54045 rows x 9 columns]

# %%
y_train = data_train_df['Winner_num']

# %%
X_train = data_train_df.drop('Winner_num',axis=1)

# %%
X_test = data_test_df.drop('Winner_num',axis=1)

# %%
y_test = data_test_df['Winner_num']

# %%
data_train_df
# Out:
#         Wickets taken  Remaining Team Value  Remaining Average Team Value
# 0           -0.456910              0.655180                      0.607048  \
# 1           -0.456910              0.655180                      0.607048
# 2           -0.456910              0.655180                      0.607048
# 3           -0.456910              0.655180                      0.607048
# 4           -0.456910              0.655180                      0.607048
# ...               ...                   ...                           ...
# 329569      -1.103657              1.214153                      0.919880
# 329570      -0.456910              0.841504                      0.958196
# 329571       0.801180             -0.649088                      0.013576
# 329572       0.454629             -0.462764                     -0.406114
# 329573       1.366168             -1.580709                     -1.554742
#
#         Start Team Value  Ground RPO  Ground RPW  Winner_num
# 0              -0.098918   -0.346523   -0.232473           1  \
# 1              -0.098918   -0.346523   -0.232473           1
# 2              -0.098918   -0.346523   -0.232473           1
# 3              -0.098918   -0.346523   -0.232473           1
# 4              -0.098918   -0.346523   -0.232473           1
# ...                  ...         ...         ...         ...
# 329569         -0.098918    0.412043    0.344080           3
# 329570          0.467671    0.252482    0.598053           3
# 329571         -0.098918    0.252482    0.341475           3
# 329572         -1.303464   -2.103724   -2.208669           3
# 329573         -1.303464    0.412043    0.344080           3
#
#         Remaining overs and balls  Remainder
# 0                        1.012697   1.075316
# 1                        1.005512   1.070467
# 2                        0.991020   1.060720
# 3                        0.983712   1.055823
# 4                        0.968972   1.026092
# ...                           ...        ...
# 329569                   0.811488   0.861623
# 329570                   0.267423   0.249775
# 329571                  -1.698283  -1.804136
# 329572                  -0.187144  -0.253504
# 329573                  -2.851100  -2.776083
#
# [329574 rows x 9 columns]

# %% [markdown]
# Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train
# Out:
#         Wickets taken  Remaining Team Value  Remaining Average Team Value
# 0           -0.456910              0.655180                      0.607048  \
# 1           -0.456910              0.655180                      0.607048
# 2           -0.456910              0.655180                      0.607048
# 3           -0.456910              0.655180                      0.607048
# 4           -0.456910              0.655180                      0.607048
# ...               ...                   ...                           ...
# 329569      -1.103657              1.214153                      0.919880
# 329570      -0.456910              0.841504                      0.958196
# 329571       0.801180             -0.649088                      0.013576
# 329572       0.454629             -0.462764                     -0.406114
# 329573       1.366168             -1.580709                     -1.554742
#
#         Start Team Value  Ground RPO  Ground RPW  Remaining overs and balls
# 0              -0.098918   -0.346523   -0.232473                   1.012697  \
# 1              -0.098918   -0.346523   -0.232473                   1.005512
# 2              -0.098918   -0.346523   -0.232473                   0.991020
# 3              -0.098918   -0.346523   -0.232473                   0.983712
# 4              -0.098918   -0.346523   -0.232473                   0.968972
# ...                  ...         ...         ...                        ...
# 329569         -0.098918    0.412043    0.344080                   0.811488
# 329570          0.467671    0.252482    0.598053                   0.267423
# 329571         -0.098918    0.252482    0.341475                  -1.698283
# 329572         -1.303464   -2.103724   -2.208669                  -0.187144
# 329573         -1.303464    0.412043    0.344080                  -2.851100
#
#         Remainder
# 0        1.075316
# 1        1.070467
# 2        1.060720
# 3        1.055823
# 4        1.026092
# ...           ...
# 329569   0.861623
# 329570   0.249775
# 329571  -1.804136
# 329572  -0.253504
# 329573  -2.776083
#
# [329574 rows x 8 columns]

# %%
rnd_clf = RandomForestClassifier(random_state=7)
rnd_clf.fit(X_train, y_train)

y_pred_rf = rnd_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

accuracy = accuracy_score(y_test, y_pred_rf)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5081506152280507

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV, train_test_split


param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}

# Create a random forest classifier
rf = RandomForestClassifier()

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf, 
                                 param_distributions = param_dist, 
                                 n_iter=5, 
                                 cv=5)

# Fit the random search object to the data
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002363DCD97E0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000236288727D0>})

# %%
# Create a variable for the best model
best_rf = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 13, 'n_estimators': 241}

# %%
rnd_clf = RandomForestClassifier(n_estimators=95, max_depth=19,
                                 n_jobs=-1, random_state=7)
rnd_clf.fit(X_train, y_train)

y_tweaked_pred_rf = rnd_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

accuracy = accuracy_score(y_test, y_tweaked_pred_rf)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5081506152280507

# %%
# Create a series containing feature importances from the model and feature names from the training data
feature_importances = pd.Series(best_rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# Plot a simple bar chart
feature_importances.plot.bar();

# %% [markdown]
# https://www.datacamp.com/tutorial/random-forests-classifier-python

# %% [markdown]
# Neural Network

# %%
hidden_units = 10     # how many neurons in the hidden layer
activation = 'relu'   # activation function for hidden layer
l2 = 0.01             # regularization - how much we penalize large parameter values
learning_rate = 0.01  # how big our steps are in gradient descent
epochs = 5            # how many epochs to train for
batch_size = 16       # how many samples to use for each gradient descent update

# %%
pip install keras
pip install tqdm
# !pip3 install tensorflow
# Out:
# Requirement already satisfied: keras in c:\users\carth\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import math
from keras import models, layers, optimizers, regularizers
import numpy as np
import random
from sklearn import model_selection, preprocessing
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
# create a sequential model
model = models.Sequential()

# add the hidden layer
model.add(layers.Dense(input_dim=len(features),
                       units=hidden_units, 
                       activation=activation))

# add the output layer
model.add(layers.Dense(input_dim=hidden_units,
                       units=1,
                       activation='sigmoid'))

# define our loss function and optimizer
model.compile(loss='binary_crossentropy',
              # Adam is a kind of gradient descent
              optimizer=optimizers.Adam(lr=learning_rate),
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Sophie Folder\Birkbeck\Project\Git\DLS_Project\Project_model.ipynb Cell 29 line 5
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> model = models.Sequential()
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=3'>4</a> # add the hidden layer
# ----> <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=4'>5</a> model.add(layers.Dense(input_dim=len(features),
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=5'>6</a>                        units=hidden_units,
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=6'>7</a>                        activation=activation))
#       <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=8'>9</a> # add the output layer
#      <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=9'>10</a> model.add(layers.Dense(input_dim=hidden_units,
#      <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=10'>11</a>                        units=1,
#      <a href='vscode-notebook-cell:/c%3A/Sophie%20Folder/Birkbeck/Project/Git/DLS_Project/Project_model.ipynb#X40sZmlsZQ%3D%3D?line=11'>12</a>                        activation='sigmoid'))
#
# NameError: name 'features' is not defined

# %% [markdown]
# https://www.kaggle.com/code/timniven/feedforward-neural-network-tutorial
