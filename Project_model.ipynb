# %%
import pandas as pd

# %%
data_train_df = pd.read_csv("data_train_transformed_csv")
data_test_df = pd.read_csv("data_test_csv")

# %%
data_train_df = data_train_df.drop(['Unnamed: 0', 'Row ID'], axis=1)
data_test_df = data_test_df.drop(''Unnamed: 0', 'Row ID'], axis=1)

# %%
data_train_df
# Out:
#         Row ID  Wickets taken  Remaining Team Value
# 0            0      -0.456910              0.655180  \
# 1            1      -0.456910              0.655180
# 2            3      -0.456910              0.655180
# 3            4      -0.456910              0.655180
# 4            6      -0.456910              0.655180
# ...        ...            ...                   ...
# 329569   10570      -1.103657              1.214153
# 329570  199325      -0.456910              0.841504
# 329571  122245       0.801180             -0.649088
# 329572   85363       0.454629             -0.462764
# 329573   25483       1.366168             -1.580709
#
#         Remaining Average Team Value  Start Team Value  Ground RPO
# 0                           0.607048         -0.098918   -0.346523  \
# 1                           0.607048         -0.098918   -0.346523
# 2                           0.607048         -0.098918   -0.346523
# 3                           0.607048         -0.098918   -0.346523
# 4                           0.607048         -0.098918   -0.346523
# ...                              ...               ...         ...
# 329569                      0.919880         -0.098918    0.412043
# 329570                      0.958196          0.467671    0.252482
# 329571                      0.013576         -0.098918    0.252482
# 329572                     -0.406114         -1.303464   -2.103724
# 329573                     -1.554742         -1.303464    0.412043
#
#         Ground RPW  Winner_num  Remaining overs and balls  Remainder
# 0        -0.232473           1                   1.012697   1.075316
# 1        -0.232473           1                   1.005512   1.070467
# 2        -0.232473           1                   0.991020   1.060720
# 3        -0.232473           1                   0.983712   1.055823
# 4        -0.232473           1                   0.968972   1.026092
# ...            ...         ...                        ...        ...
# 329569    0.344080           3                   0.811488   0.861623
# 329570    0.598053           3                   0.267423   0.249775
# 329571    0.341475           3                  -1.698283  -1.804136
# 329572   -2.208669           3                  -0.187144  -0.253504
# 329573    0.344080           3                  -2.851100  -2.776083
#
# [329574 rows x 10 columns]

# %%
data_test_df
# Out:
#        Row ID  Wickets taken  Remaining Team Value
# 0           2              3                    16  \
# 1           5              3                    16
# 2          12              3                    16
# 3          16              3                    16
# 4          23              3                    16
# ...       ...            ...                   ...
# 54040  270198              2                    16
# 54041  270200              2                    16
# 54042  270207              3                    13
# 54043  270217              3                    13
# 54044  270222              3                    13
#
#        Remaining Average Team Value  Start Team Value  Ground RPO  Ground RPW
# 0                          2.000000                24        4.79       29.31  \
# 1                          2.000000                24        4.79       29.31
# 2                          2.000000                24        4.79       29.31
# 3                          2.000000                24        4.79       29.31
# 4                          2.000000                24        4.79       29.31
# ...                             ...               ...         ...         ...
# 54040                      1.777778                21        5.40       31.64
# 54041                      1.777778                21        5.40       31.64
# 54042                      1.625000                21        5.40       31.64
# 54043                      1.625000                21        5.40       31.64
# 54044                      1.625000                21        5.40       31.64
#
#        Winner_num  Remaining overs and balls  Remainder
# 0               1                        177       29.3
# 1               1                        174       29.0
# 2               1                        167       27.5
# 3               1                        163       27.1
# 4               1                        156       26.0
# ...           ...                        ...        ...
# 54040           2                         38        6.2
# 54041           2                         36        6.0
# 54042           2                         29        4.5
# 54043           2                         19        3.1
# 54044           2                         14        2.2
#
# [54045 rows x 10 columns]

# %%
y_train = data_train_df['Winner_num']

# %%
X_train = data_train_df.drop('Winner_num',axis=1)

# %%
X_test = data_test_df.drop('Winner_num',axis=1)

# %%
y_test = data_test_df['Winner_num']

# %%
data_train_df
# Out:
#         Row ID  Wickets taken  Remaining Team Value
# 0            0      -0.456910              0.655180  \
# 1            1      -0.456910              0.655180
# 2            3      -0.456910              0.655180
# 3            4      -0.456910              0.655180
# 4            6      -0.456910              0.655180
# ...        ...            ...                   ...
# 329569   10570      -1.103657              1.214153
# 329570  199325      -0.456910              0.841504
# 329571  122245       0.801180             -0.649088
# 329572   85363       0.454629             -0.462764
# 329573   25483       1.366168             -1.580709
#
#         Remaining Average Team Value  Start Team Value  Ground RPO
# 0                           0.607048         -0.098918   -0.346523  \
# 1                           0.607048         -0.098918   -0.346523
# 2                           0.607048         -0.098918   -0.346523
# 3                           0.607048         -0.098918   -0.346523
# 4                           0.607048         -0.098918   -0.346523
# ...                              ...               ...         ...
# 329569                      0.919880         -0.098918    0.412043
# 329570                      0.958196          0.467671    0.252482
# 329571                      0.013576         -0.098918    0.252482
# 329572                     -0.406114         -1.303464   -2.103724
# 329573                     -1.554742         -1.303464    0.412043
#
#         Ground RPW  Winner_num  Remaining overs and balls  Remainder
# 0        -0.232473           1                   1.012697   1.075316
# 1        -0.232473           1                   1.005512   1.070467
# 2        -0.232473           1                   0.991020   1.060720
# 3        -0.232473           1                   0.983712   1.055823
# 4        -0.232473           1                   0.968972   1.026092
# ...            ...         ...                        ...        ...
# 329569    0.344080           3                   0.811488   0.861623
# 329570    0.598053           3                   0.267423   0.249775
# 329571    0.341475           3                  -1.698283  -1.804136
# 329572   -2.208669           3                  -0.187144  -0.253504
# 329573    0.344080           3                  -2.851100  -2.776083
#
# [329574 rows x 10 columns]

# %% [markdown]
# Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train
# Out:
#         Row ID  Wickets taken  Remaining Team Value
# 0            0      -0.456910              0.655180  \
# 1            1      -0.456910              0.655180
# 2            3      -0.456910              0.655180
# 3            4      -0.456910              0.655180
# 4            6      -0.456910              0.655180
# ...        ...            ...                   ...
# 329569   10570      -1.103657              1.214153
# 329570  199325      -0.456910              0.841504
# 329571  122245       0.801180             -0.649088
# 329572   85363       0.454629             -0.462764
# 329573   25483       1.366168             -1.580709
#
#         Remaining Average Team Value  Start Team Value  Ground RPO
# 0                           0.607048         -0.098918   -0.346523  \
# 1                           0.607048         -0.098918   -0.346523
# 2                           0.607048         -0.098918   -0.346523
# 3                           0.607048         -0.098918   -0.346523
# 4                           0.607048         -0.098918   -0.346523
# ...                              ...               ...         ...
# 329569                      0.919880         -0.098918    0.412043
# 329570                      0.958196          0.467671    0.252482
# 329571                      0.013576         -0.098918    0.252482
# 329572                     -0.406114         -1.303464   -2.103724
# 329573                     -1.554742         -1.303464    0.412043
#
#         Ground RPW  Remaining overs and balls  Remainder
# 0        -0.232473                   1.012697   1.075316
# 1        -0.232473                   1.005512   1.070467
# 2        -0.232473                   0.991020   1.060720
# 3        -0.232473                   0.983712   1.055823
# 4        -0.232473                   0.968972   1.026092
# ...            ...                        ...        ...
# 329569    0.344080                   0.811488   0.861623
# 329570    0.598053                   0.267423   0.249775
# 329571    0.341475                  -1.698283  -1.804136
# 329572   -2.208669                  -0.187144  -0.253504
# 329573    0.344080                  -2.851100  -2.776083
#
# [329574 rows x 9 columns]

# %%
rnd_clf = RandomForestClassifier(random_state=7)
rnd_clf.fit(X_train, y_train)

y_pred_rf = rnd_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

accuracy = accuracy_score(y_test, y_pred_rf)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5043204736793413

# %%
from scipy.stats import randint
from sklearn.model_selection import RandomizedSearchCV, train_test_split


param_dist = {'n_estimators': randint(50,500),
              'max_depth': randint(1,20)}

# Create a random forest classifier
rf = RandomForestClassifier()

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf, 
                                 param_distributions = param_dist, 
                                 n_iter=5, 
                                 cv=5)

# Fit the random search object to the data
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=5,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x00000155BA9FEDA0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000015591436A70>})

# %%
# Create a variable for the best model
best_rf = rand_search.best_estimator_

# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': 19, 'n_estimators': 278}

# %%
rnd_clf = RandomForestClassifier(n_estimators=95, max_depth=19,
                                 n_jobs=-1, random_state=7)
rnd_clf.fit(X_train, y_train)

y_tweaked_pred_rf = rnd_clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

accuracy = accuracy_score(y_test, y_tweaked_pred_rf)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5085391803127024

# %%
# Create a series containing feature importances from the model and feature names from the training data
feature_importances = pd.Series(best_rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# Plot a simple bar chart
feature_importances.plot.bar();

# %% [markdown]
# https://www.datacamp.com/tutorial/random-forests-classifier-python
